# %%
import pandas as pd

# %%
df=pd.read_excel (r"C:\data\my_data.xlsx")

df
# Out:
#      Glucose   BMI  Age  BloodPressure  Insulin  SkinThickness  Diabetic
# 0        172  32.2   46            103    127.3           19.9         1
# 1        162  27.1   66             95    233.6           32.3         1
# 2         84  39.6   54            107    132.4           19.0         1
# 3        176  25.7   69             63    112.6           16.4         1
# 4        141  30.1   34             64    288.0           36.1         1
# ..       ...   ...  ...            ...      ...            ...       ...
# 295      168  25.9   53             66     63.8           14.5         0
# 296      124  23.2   67             69    144.0           10.1         1
# 297      121  20.9   60            104     10.4           35.5         1
# 298       82  21.7   63             76    183.5           30.6         0
# 299      183  30.7   32             85    186.1           33.7         1
#
# [300 rows x 7 columns]
